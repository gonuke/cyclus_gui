# %%
import xmltodict
import numpy as np
import json
import simplejson
from pprint import pprint
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-47-d5bd684ca80f> in <module>
#       2 import numpy as np
#       3 import json
# ----> 4 import simplejson
#       5 from pprint import pprint
#
# ModuleNotFoundError: No module named 'simplejson'

# %%
schema_dict = {'cyclus':{}}

f = open('schema.xml').read()
x = xmltodict.parse(f)
pprint(x)
# Out:
# OrderedDict([('grammar',
#               OrderedDict([('@xmlns', 'http://relaxng.org/ns/structure/1.0'),
#                            ('@datatypeLibrary',
#                             'http://www.w3.org/2001/XMLSchema-datatypes'),
#                            ('start',
#                             OrderedDict([('element',
#                                           OrderedDict([('@name', 'simulation'),
#                                                        ('optional',
#                                                         OrderedDict([('element',
#                                                                       OrderedDict([('@name',
#                                                                                     'schematype'),
#                                                                                    ('text',
#                                                                                     None)]))])),
#                                                        ('interleave',
#                                                         OrderedDict([('optional',
#                                                                       OrderedDict([('element',
#                                                                                     OrderedDict([('@name',
#                                                                                                   'ui'),
#                                                                                                  ('text',
#                                                                                                   None)]))])),
#                                                                      ('element',
#                                                                       [OrderedDict([('@name',
#                                                                                      'control'),
#                                                                                     ('interleave',
#                                                                                      OrderedDict([('optional',
#                                                                                                    [OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'simhandle'),
#                                                                                                                                ('data',
#                                                                                                                                 OrderedDict([('@type',
#                                                                                                                                               'string')]))]))]),
#                                                                                                     OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'decay'),
#                                                                                                                                ('text',
#                                                                                                                                 None)]))]),
#                                                                                                     OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'dt'),
#                                                                                                                                ('data',
#                                                                                                                                 OrderedDict([('@type',
#                                                                                                                                               'nonNegativeInteger')]))]))]),
#                                                                                                     OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'explicit_inventory'),
#                                                                                                                                ('data',
#                                                                                                                                 OrderedDict([('@type',
#                                                                                                                                               'boolean')]))]))]),
#                                                                                                     OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'explicit_inventory_compact'),
#                                                                                                                                ('data',
#                                                                                                                                 OrderedDict([('@type',
#                                                                                                                                               'boolean')]))]))]),
#                                                                                                     OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'tolerance_generic'),
#                                                                                                                                ('data',
#                                                                                                                                 OrderedDict([('@type',
#                                                                                                                                               'double')]))]))]),
#                                                                                                     OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'tolerance_resource'),
#                                                                                                                                ('data',
#                                                                                                                                 OrderedDict([('@type',
#                                                                                                                                               'double')]))]))]),
#                                                                                                     OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'solver'),
#                                                                                                                                ('interleave',
#                                                                                                                                 OrderedDict([('optional',
#                                                                                                                                               [OrderedDict([('element',
#                                                                                                                                                              OrderedDict([('@name',
#                                                                                                                                                                            'config'),
#                                                                                                                                                                           ('choice',
#                                                                                                                                                                            OrderedDict([('element',
#                                                                                                                                                                                          [OrderedDict([('@name',
#                                                                                                                                                                                                         'greedy'),
#                                                                                                                                                                                                        ('interleave',
#                                                                                                                                                                                                         OrderedDict([('optional',
#                                                                                                                                                                                                                       OrderedDict([('element',
#                                                                                                                                                                                                                                     OrderedDict([('@name',
#                                                                                                                                                                                                                                                   'preconditioner'),
#                                                                                                                                                                                                                                                  ('text',
#                                                                                                                                                                                                                                                   None)]))]))]))]),
#                                                                                                                                                                                           OrderedDict([('@name',
#                                                                                                                                                                                                         'coin-or'),
#                                                                                                                                                                                                        ('interleave',
#                                                                                                                                                                                                         OrderedDict([('optional',
#                                                                                                                                                                                                                       [OrderedDict([('element',
#                                                                                                                                                                                                                                      OrderedDict([('@name',
#                                                                                                                                                                                                                                                    'timeout'),
#                                                                                                                                                                                                                                                   ('data',
#                                                                                                                                                                                                                                                    OrderedDict([('@type',
#                                                                                                                                                                                                                                                                  'positiveInteger')]))]))]),
#                                                                                                                                                                                                                        OrderedDict([('element',
#                                                                                                                                                                                                                                      OrderedDict([('@name',
#                                                                                                                                                                                                                                                    'verbose'),
#                                                                                                                                                                                                                                                   ('data',
#                                                                                                                                                                                                                                                    OrderedDict([('@type',
#                                                                                                                                                                                                                                                                  'boolean')]))]))]),
#                                                                                                                                                                                                                        OrderedDict([('element',
#                                                                                                                                                                                                                                      OrderedDict([('@name',
#                                                                                                                                                                                                                                                    'mps'),
#                                                                                                                                                                                                                                                   ('data',
#                                                                                                                                                                                                                                                    OrderedDict([('@type',
#                                                                                                                                                                                                                                                                  'boolean')]))]))])])]))])])]))]))]),
#                                                                                                                                                OrderedDict([('element',
#                                                                                                                                                              OrderedDict([('@name',
#                                                                                                                                                                            'allow_exclusive_orders'),
#                                                                                                                                                                           ('data',
#                                                                                                                                                                            OrderedDict([('@type',
#                                                                                                                                                                                          'boolean')]))]))]),
#                                                                                                                                                OrderedDict([('element',
#                                                                                                                                                              OrderedDict([('@name',
#                                                                                                                                                                            'exclusive_orders_only'),
#                                                                                                                                                                           ('data',
#                                                                                                                                                                            OrderedDict([('@type',
#                                                                                                                                                                                          'boolean')]))]))])])]))]))])]),
#                                                                                                   ('element',
#                                                                                                    [OrderedDict([('@name',
#                                                                                                                   'duration'),
#                                                                                                                  ('data',
#                                                                                                                   OrderedDict([('@type',
#                                                                                                                                 'nonNegativeInteger')]))]),
#                                                                                                     OrderedDict([('@name',
#                                                                                                                   'startmonth'),
#                                                                                                                  ('data',
#                                                                                                                   OrderedDict([('@type',
#                                                                                                                                 'nonNegativeInteger')]))]),
#                                                                                                     OrderedDict([('@name',
#                                                                                                                   'startyear'),
#                                                                                                                  ('data',
#                                                                                                                   OrderedDict([('@type',
#                                                                                                                                 'nonNegativeInteger')]))])])]))]),
#                                                                        OrderedDict([('@name',
#                                                                                      'archetypes'),
#                                                                                     ('oneOrMore',
#                                                                                      OrderedDict([('element',
#                                                                                                    OrderedDict([('@name',
#                                                                                                                  'spec'),
#                                                                                                                 ('interleave',
#                                                                                                                  OrderedDict([('optional',
#                                                                                                                                [OrderedDict([('element',
#                                                                                                                                               OrderedDict([('@name',
#                                                                                                                                                             'path'),
#                                                                                                                                                            ('text',
#                                                                                                                                                             None)]))]),
#                                                                                                                                 OrderedDict([('element',
#                                                                                                                                               OrderedDict([('@name',
#                                                                                                                                                             'lib'),
#                                                                                                                                                            ('text',
#                                                                                                                                                             None)]))]),
#                                                                                                                                 OrderedDict([('element',
#                                                                                                                                               OrderedDict([('@name',
#                                                                                                                                                             'alias'),
#                                                                                                                                                            ('text',
#                                                                                                                                                             None)]))])]),
#                                                                                                                               ('element',
#                                                                                                                                OrderedDict([('@name',
#                                                                                                                                              'name'),
#                                                                                                                                             ('text',
#                                                                                                                                              None)]))]))]))]))])]),
#                                                                      ('zeroOrMore',
#                                                                       [OrderedDict([('element',
#                                                                                      OrderedDict([('@name',
#                                                                                                    'commodity'),
#                                                                                                   ('interleave',
#                                                                                                    OrderedDict([('element',
#                                                                                                                  [OrderedDict([('@name',
#                                                                                                                                 'name'),
#                                                                                                                                ('text',
#                                                                                                                                 None)]),
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'solution_priority'),
#                                                                                                                                ('data',
#                                                                                                                                 OrderedDict([('@type',
#                                                                                                                                               'double')]))])])]))]))]),
#                                                                        OrderedDict([('element',
#                                                                                      OrderedDict([('@name',
#                                                                                                    'recipe'),
#                                                                                                   ('interleave',
#                                                                                                    OrderedDict([('element',
#                                                                                                                  [OrderedDict([('@name',
#                                                                                                                                 'name'),
#                                                                                                                                ('text',
#                                                                                                                                 None)]),
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'basis'),
#                                                                                                                                ('text',
#                                                                                                                                 None)])]),
#                                                                                                                 ('oneOrMore',
#                                                                                                                  OrderedDict([('element',
#                                                                                                                                OrderedDict([('@name',
#                                                                                                                                              'nuclide'),
#                                                                                                                                             ('interleave',
#                                                                                                                                              OrderedDict([('element',
#                                                                                                                                                            [OrderedDict([('@name',
#                                                                                                                                                                           'id'),
#                                                                                                                                                                          ('data',
#                                                                                                                                                                           OrderedDict([('@type',
#                                                                                                                                                                                         'string')]))]),
#                                                                                                                                                             OrderedDict([('@name',
#                                                                                                                                                                           'comp'),
#                                                                                                                                                                          ('data',
#                                                                                                                                                                           OrderedDict([('@type',
#                                                                                                                                                                                         'double')]))])])]))]))]))]))]))])]),
#                                                                      ('oneOrMore',
#                                                                       [OrderedDict([('element',
#                                                                                      OrderedDict([('@name',
#                                                                                                    'facility'),
#                                                                                                   ('interleave',
#                                                                                                    OrderedDict([('element',
#                                                                                                                  [OrderedDict([('@name',
#                                                                                                                                 'name'),
#                                                                                                                                ('text',
#                                                                                                                                 None)]),
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'config'),
#                                                                                                                                ('choice',
#                                                                                                                                 '@Facility_REFS@')])]),
#                                                                                                                 ('optional',
#                                                                                                                  OrderedDict([('element',
#                                                                                                                                OrderedDict([('@name',
#                                                                                                                                              'lifetime'),
#                                                                                                                                             ('data',
#                                                                                                                                              OrderedDict([('@type',
#                                                                                                                                                            'nonNegativeInteger')]))]))]))]))]))]),
#                                                                        OrderedDict([('element',
#                                                                                      OrderedDict([('@name',
#                                                                                                    'region'),
#                                                                                                   ('interleave',
#                                                                                                    OrderedDict([('element',
#                                                                                                                  [OrderedDict([('@name',
#                                                                                                                                 'name'),
#                                                                                                                                ('text',
#                                                                                                                                 None)]),
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'config'),
#                                                                                                                                ('choice',
#                                                                                                                                 '@Region_REFS@')])]),
#                                                                                                                 ('optional',
#                                                                                                                  OrderedDict([('element',
#                                                                                                                                OrderedDict([('@name',
#                                                                                                                                              'lifetime'),
#                                                                                                                                             ('data',
#                                                                                                                                              OrderedDict([('@type',
#                                                                                                                                                            'nonNegativeInteger')]))]))])),
#                                                                                                                 ('oneOrMore',
#                                                                                                                  OrderedDict([('element',
#                                                                                                                                OrderedDict([('@name',
#                                                                                                                                              'institution'),
#                                                                                                                                             ('interleave',
#                                                                                                                                              OrderedDict([('element',
#                                                                                                                                                            [OrderedDict([('@name',
#                                                                                                                                                                           'name'),
#                                                                                                                                                                          ('text',
#                                                                                                                                                                           None)]),
#                                                                                                                                                             OrderedDict([('@name',
#                                                                                                                                                                           'config'),
#                                                                                                                                                                          ('choice',
#                                                                                                                                                                           '@Inst_REFS@')])]),
#                                                                                                                                                           ('optional',
#                                                                                                                                                            [OrderedDict([('element',
#                                                                                                                                                                           OrderedDict([('@name',
#                                                                                                                                                                                         'lifetime'),
#                                                                                                                                                                                        ('data',
#                                                                                                                                                                                         OrderedDict([('@type',
#                                                                                                                                                                                                       'nonNegativeInteger')]))]))]),
#                                                                                                                                                             OrderedDict([('element',
#                                                                                                                                                                           OrderedDict([('@name',
#                                                                                                                                                                                         'initialfacilitylist'),
#                                                                                                                                                                                        ('oneOrMore',
#                                                                                                                                                                                         OrderedDict([('element',
#                                                                                                                                                                                                       OrderedDict([('@name',
#                                                                                                                                                                                                                     'entry'),
#                                                                                                                                                                                                                    ('interleave',
#                                                                                                                                                                                                                     OrderedDict([('element',
#                                                                                                                                                                                                                                   [OrderedDict([('@name',
#                                                                                                                                                                                                                                                  'prototype'),
#                                                                                                                                                                                                                                                 ('text',
#                                                                                                                                                                                                                                                  None)]),
#                                                                                                                                                                                                                                    OrderedDict([('@name',
#                                                                                                                                                                                                                                                  'number'),
#                                                                                                                                                                                                                                                 ('data',
#                                                                                                                                                                                                                                                  OrderedDict([('@type',
#                                                                                                                                                                                                                                                                'nonNegativeInteger')]))])])]))]))]))]))])])]))]))]))]))]))])])]))]))]))]))])

# %%
i = x['grammar']['start']['element']['interleave']
i.keys()
# Out:
# odict_keys(['optional', 'element', 'zeroOrMore', 'oneOrMore'])

# %%
for j in i['element']:
    print(j['@name'])
    for k in j.keys():
        pprint(j[k])
# Out:
# control
# 'control'
# OrderedDict([('optional',
#               [OrderedDict([('element',
#                              OrderedDict([('@name', 'simhandle'),
#                                           ('data',
#                                            OrderedDict([('@type',
#                                                          'string')]))]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name', 'decay'),
#                                           ('text', None)]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name', 'dt'),
#                                           ('data',
#                                            OrderedDict([('@type',
#                                                          'nonNegativeInteger')]))]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name', 'explicit_inventory'),
#                                           ('data',
#                                            OrderedDict([('@type',
#                                                          'boolean')]))]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name',
#                                            'explicit_inventory_compact'),
#                                           ('data',
#                                            OrderedDict([('@type',
#                                                          'boolean')]))]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name', 'tolerance_generic'),
#                                           ('data',
#                                            OrderedDict([('@type',
#                                                          'double')]))]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name', 'tolerance_resource'),
#                                           ('data',
#                                            OrderedDict([('@type',
#                                                          'double')]))]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name', 'solver'),
#                                           ('interleave',
#                                            OrderedDict([('optional',
#                                                          [OrderedDict([('element',
#                                                                         OrderedDict([('@name',
#                                                                                       'config'),
#                                                                                      ('choice',
#                                                                                       OrderedDict([('element',
#                                                                                                     [OrderedDict([('@name',
#                                                                                                                    'greedy'),
#                                                                                                                   ('interleave',
#                                                                                                                    OrderedDict([('optional',
#                                                                                                                                  OrderedDict([('element',
#                                                                                                                                                OrderedDict([('@name',
#                                                                                                                                                              'preconditioner'),
#                                                                                                                                                             ('text',
#                                                                                                                                                              None)]))]))]))]),
#                                                                                                      OrderedDict([('@name',
#                                                                                                                    'coin-or'),
#                                                                                                                   ('interleave',
#                                                                                                                    OrderedDict([('optional',
#                                                                                                                                  [OrderedDict([('element',
#                                                                                                                                                 OrderedDict([('@name',
#                                                                                                                                                               'timeout'),
#                                                                                                                                                              ('data',
#                                                                                                                                                               OrderedDict([('@type',
#                                                                                                                                                                             'positiveInteger')]))]))]),
#                                                                                                                                   OrderedDict([('element',
#                                                                                                                                                 OrderedDict([('@name',
#                                                                                                                                                               'verbose'),
#                                                                                                                                                              ('data',
#                                                                                                                                                               OrderedDict([('@type',
#                                                                                                                                                                             'boolean')]))]))]),
#                                                                                                                                   OrderedDict([('element',
#                                                                                                                                                 OrderedDict([('@name',
#                                                                                                                                                               'mps'),
#                                                                                                                                                              ('data',
#                                                                                                                                                               OrderedDict([('@type',
#                                                                                                                                                                             'boolean')]))]))])])]))])])]))]))]),
#                                                           OrderedDict([('element',
#                                                                         OrderedDict([('@name',
#                                                                                       'allow_exclusive_orders'),
#                                                                                      ('data',
#                                                                                       OrderedDict([('@type',
#                                                                                                     'boolean')]))]))]),
#                                                           OrderedDict([('element',
#                                                                         OrderedDict([('@name',
#                                                                                       'exclusive_orders_only'),
#                                                                                      ('data',
#                                                                                       OrderedDict([('@type',
#                                                                                                     'boolean')]))]))])])]))]))])]),
#              ('element',
#               [OrderedDict([('@name', 'duration'),
#                             ('data',
#                              OrderedDict([('@type', 'nonNegativeInteger')]))]),
#                OrderedDict([('@name', 'startmonth'),
#                             ('data',
#                              OrderedDict([('@type', 'nonNegativeInteger')]))]),
#                OrderedDict([('@name', 'startyear'),
#                             ('data',
#                              OrderedDict([('@type',
#                                            'nonNegativeInteger')]))])])])
# archetypes
# 'archetypes'
# OrderedDict([('element',
#               OrderedDict([('@name', 'spec'),
#                            ('interleave',
#                             OrderedDict([('optional',
#                                           [OrderedDict([('element',
#                                                          OrderedDict([('@name',
#                                                                        'path'),
#                                                                       ('text',
#                                                                        None)]))]),
#                                            OrderedDict([('element',
#                                                          OrderedDict([('@name',
#                                                                        'lib'),
#                                                                       ('text',
#                                                                        None)]))]),
#                                            OrderedDict([('element',
#                                                          OrderedDict([('@name',
#                                                                        'alias'),
#                                                                       ('text',
#                                                                        None)]))])]),
#                                          ('element',
#                                           OrderedDict([('@name', 'name'),
#                                                        ('text', None)]))]))]))])

# %%
for j in i['zeroOrMore']:
    print(j['element']['@name'])
# Out:
# commodity
# recipe

# %%
for j in i['oneOrMore']:
    print(j['element']['@name'])
# Out:
# facility
# region

# %%
for j in i['optional']:
    print(j)
# Out:
# element

# %%
def convert_valtype(valtype):
    # conversion from Cyclus valtype [key]
    # to Workbench ValType [val]
    conversion_dict = {'string': 'String',
                       'nonNegativeInteger': 'Int',
                       'boolean': 'Int',
                       'double': 'Real',
                       'positiveInteger': 'Int',
                       'float': 'Real',
                       'double': 'Real',
                       'duration': 'Int',
                       'integer': 'Int',
                       'nonPositiveInteger': 'Int',
                       'negativeInteger': 'Int',
                       'long': 'Real',
                       'int': 'Int',
                       }

    additional_dict = {'nonNegativeInteger': {'MinValInc': 0},
                       'positiveInteger': {'MinValExc': 0},
                       'boolean': {'ValEnums': [0, 1]},
                       'duration': {'MinValInc': 0},
                       'nonPositiveInteger': {'MaxValInc': 0},
                       'negativeInteger': {'MaxValExc': 0},
                       }
    d = {'valType': conversion_dict[valtype]}
    if valtype in additional_dict:
        for key, val in additional_dict[valtype].items():
            d[key] = val
    return d

def convert_num_limits(limit_type):
    conversion_dict = {'oneOrMore': {'MinOccurs': 1},
                       'zeroOrMore': {'MinOccurs': 0}
                       }


def change_element(element_dict):
    d = {element_dict['@name']: convert_valtype(element_dict['data']['@type'])}
# Out:
# {'valType': 'Int', 'MaxValInc': 0}

# %%
# Out:
# '{"element": {"@name": "spec", "interleave": {"optional": [{"element": {"@name": "path", "text": null}}, {"element": {"@name": "lib", "text": null}}, {"element": {"@name": "alias", "text": null}}], "element": {"@name": "name", "text": null}}}}'

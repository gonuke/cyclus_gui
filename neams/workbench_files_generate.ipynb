# %%
import xmltodict
import numpy as np
import json
import os
from pprint import pprint

# %%
schema_dict = {'cyclus':{}}

f = open('schema.xml').read()
x = xmltodict.parse(f)
pprint(x)
# Out:
# OrderedDict([('grammar',
#               OrderedDict([('@xmlns', 'http://relaxng.org/ns/structure/1.0'),
#                            ('@datatypeLibrary',
#                             'http://www.w3.org/2001/XMLSchema-datatypes'),
#                            ('start',
#                             OrderedDict([('element',
#                                           OrderedDict([('@name', 'simulation'),
#                                                        ('optional',
#                                                         OrderedDict([('element',
#                                                                       OrderedDict([('@name',
#                                                                                     'schematype'),
#                                                                                    ('text',
#                                                                                     None)]))])),
#                                                        ('interleave',
#                                                         OrderedDict([('optional',
#                                                                       OrderedDict([('element',
#                                                                                     OrderedDict([('@name',
#                                                                                                   'ui'),
#                                                                                                  ('text',
#                                                                                                   None)]))])),
#                                                                      ('element',
#                                                                       [OrderedDict([('@name',
#                                                                                      'control'),
#                                                                                     ('interleave',
#                                                                                      OrderedDict([('optional',
#                                                                                                    [OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'simhandle'),
#                                                                                                                                ('data',
#                                                                                                                                 OrderedDict([('@type',
#                                                                                                                                               'string')]))]))]),
#                                                                                                     OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'decay'),
#                                                                                                                                ('text',
#                                                                                                                                 None)]))]),
#                                                                                                     OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'dt'),
#                                                                                                                                ('data',
#                                                                                                                                 OrderedDict([('@type',
#                                                                                                                                               'nonNegativeInteger')]))]))]),
#                                                                                                     OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'explicit_inventory'),
#                                                                                                                                ('data',
#                                                                                                                                 OrderedDict([('@type',
#                                                                                                                                               'boolean')]))]))]),
#                                                                                                     OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'explicit_inventory_compact'),
#                                                                                                                                ('data',
#                                                                                                                                 OrderedDict([('@type',
#                                                                                                                                               'boolean')]))]))]),
#                                                                                                     OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'tolerance_generic'),
#                                                                                                                                ('data',
#                                                                                                                                 OrderedDict([('@type',
#                                                                                                                                               'double')]))]))]),
#                                                                                                     OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'tolerance_resource'),
#                                                                                                                                ('data',
#                                                                                                                                 OrderedDict([('@type',
#                                                                                                                                               'double')]))]))]),
#                                                                                                     OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'solver'),
#                                                                                                                                ('interleave',
#                                                                                                                                 OrderedDict([('optional',
#                                                                                                                                               [OrderedDict([('element',
#                                                                                                                                                              OrderedDict([('@name',
#                                                                                                                                                                            'config'),
#                                                                                                                                                                           ('choice',
#                                                                                                                                                                            OrderedDict([('element',
#                                                                                                                                                                                          [OrderedDict([('@name',
#                                                                                                                                                                                                         'greedy'),
#                                                                                                                                                                                                        ('interleave',
#                                                                                                                                                                                                         OrderedDict([('optional',
#                                                                                                                                                                                                                       OrderedDict([('element',
#                                                                                                                                                                                                                                     OrderedDict([('@name',
#                                                                                                                                                                                                                                                   'preconditioner'),
#                                                                                                                                                                                                                                                  ('text',
#                                                                                                                                                                                                                                                   None)]))]))]))]),
#                                                                                                                                                                                           OrderedDict([('@name',
#                                                                                                                                                                                                         'coin-or'),
#                                                                                                                                                                                                        ('interleave',
#                                                                                                                                                                                                         OrderedDict([('optional',
#                                                                                                                                                                                                                       [OrderedDict([('element',
#                                                                                                                                                                                                                                      OrderedDict([('@name',
#                                                                                                                                                                                                                                                    'timeout'),
#                                                                                                                                                                                                                                                   ('data',
#                                                                                                                                                                                                                                                    OrderedDict([('@type',
#                                                                                                                                                                                                                                                                  'positiveInteger')]))]))]),
#                                                                                                                                                                                                                        OrderedDict([('element',
#                                                                                                                                                                                                                                      OrderedDict([('@name',
#                                                                                                                                                                                                                                                    'verbose'),
#                                                                                                                                                                                                                                                   ('data',
#                                                                                                                                                                                                                                                    OrderedDict([('@type',
#                                                                                                                                                                                                                                                                  'boolean')]))]))]),
#                                                                                                                                                                                                                        OrderedDict([('element',
#                                                                                                                                                                                                                                      OrderedDict([('@name',
#                                                                                                                                                                                                                                                    'mps'),
#                                                                                                                                                                                                                                                   ('data',
#                                                                                                                                                                                                                                                    OrderedDict([('@type',
#                                                                                                                                                                                                                                                                  'boolean')]))]))])])]))])])]))]))]),
#                                                                                                                                                OrderedDict([('element',
#                                                                                                                                                              OrderedDict([('@name',
#                                                                                                                                                                            'allow_exclusive_orders'),
#                                                                                                                                                                           ('data',
#                                                                                                                                                                            OrderedDict([('@type',
#                                                                                                                                                                                          'boolean')]))]))]),
#                                                                                                                                                OrderedDict([('element',
#                                                                                                                                                              OrderedDict([('@name',
#                                                                                                                                                                            'exclusive_orders_only'),
#                                                                                                                                                                           ('data',
#                                                                                                                                                                            OrderedDict([('@type',
#                                                                                                                                                                                          'boolean')]))]))])])]))]))])]),
#                                                                                                   ('element',
#                                                                                                    [OrderedDict([('@name',
#                                                                                                                   'duration'),
#                                                                                                                  ('data',
#                                                                                                                   OrderedDict([('@type',
#                                                                                                                                 'nonNegativeInteger')]))]),
#                                                                                                     OrderedDict([('@name',
#                                                                                                                   'startmonth'),
#                                                                                                                  ('data',
#                                                                                                                   OrderedDict([('@type',
#                                                                                                                                 'nonNegativeInteger')]))]),
#                                                                                                     OrderedDict([('@name',
#                                                                                                                   'startyear'),
#                                                                                                                  ('data',
#                                                                                                                   OrderedDict([('@type',
#                                                                                                                                 'nonNegativeInteger')]))])])]))]),
#                                                                        OrderedDict([('@name',
#                                                                                      'archetypes'),
#                                                                                     ('oneOrMore',
#                                                                                      OrderedDict([('element',
#                                                                                                    OrderedDict([('@name',
#                                                                                                                  'spec'),
#                                                                                                                 ('interleave',
#                                                                                                                  OrderedDict([('optional',
#                                                                                                                                [OrderedDict([('element',
#                                                                                                                                               OrderedDict([('@name',
#                                                                                                                                                             'path'),
#                                                                                                                                                            ('text',
#                                                                                                                                                             None)]))]),
#                                                                                                                                 OrderedDict([('element',
#                                                                                                                                               OrderedDict([('@name',
#                                                                                                                                                             'lib'),
#                                                                                                                                                            ('text',
#                                                                                                                                                             None)]))]),
#                                                                                                                                 OrderedDict([('element',
#                                                                                                                                               OrderedDict([('@name',
#                                                                                                                                                             'alias'),
#                                                                                                                                                            ('text',
#                                                                                                                                                             None)]))])]),
#                                                                                                                               ('element',
#                                                                                                                                OrderedDict([('@name',
#                                                                                                                                              'name'),
#                                                                                                                                             ('text',
#                                                                                                                                              None)]))]))]))]))])]),
#                                                                      ('zeroOrMore',
#                                                                       [OrderedDict([('element',
#                                                                                      OrderedDict([('@name',
#                                                                                                    'commodity'),
#                                                                                                   ('interleave',
#                                                                                                    OrderedDict([('element',
#                                                                                                                  [OrderedDict([('@name',
#                                                                                                                                 'name'),
#                                                                                                                                ('text',
#                                                                                                                                 None)]),
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'solution_priority'),
#                                                                                                                                ('data',
#                                                                                                                                 OrderedDict([('@type',
#                                                                                                                                               'double')]))])])]))]))]),
#                                                                        OrderedDict([('element',
#                                                                                      OrderedDict([('@name',
#                                                                                                    'recipe'),
#                                                                                                   ('interleave',
#                                                                                                    OrderedDict([('element',
#                                                                                                                  [OrderedDict([('@name',
#                                                                                                                                 'name'),
#                                                                                                                                ('text',
#                                                                                                                                 None)]),
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'basis'),
#                                                                                                                                ('text',
#                                                                                                                                 None)])]),
#                                                                                                                 ('oneOrMore',
#                                                                                                                  OrderedDict([('element',
#                                                                                                                                OrderedDict([('@name',
#                                                                                                                                              'nuclide'),
#                                                                                                                                             ('interleave',
#                                                                                                                                              OrderedDict([('element',
#                                                                                                                                                            [OrderedDict([('@name',
#                                                                                                                                                                           'id'),
#                                                                                                                                                                          ('data',
#                                                                                                                                                                           OrderedDict([('@type',
#                                                                                                                                                                                         'string')]))]),
#                                                                                                                                                             OrderedDict([('@name',
#                                                                                                                                                                           'comp'),
#                                                                                                                                                                          ('data',
#                                                                                                                                                                           OrderedDict([('@type',
#                                                                                                                                                                                         'double')]))])])]))]))]))]))]))])]),
#                                                                      ('oneOrMore',
#                                                                       [OrderedDict([('element',
#                                                                                      OrderedDict([('@name',
#                                                                                                    'facility'),
#                                                                                                   ('interleave',
#                                                                                                    OrderedDict([('element',
#                                                                                                                  [OrderedDict([('@name',
#                                                                                                                                 'name'),
#                                                                                                                                ('text',
#                                                                                                                                 None)]),
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'config'),
#                                                                                                                                ('choice',
#                                                                                                                                 '@Facility_REFS@')])]),
#                                                                                                                 ('optional',
#                                                                                                                  OrderedDict([('element',
#                                                                                                                                OrderedDict([('@name',
#                                                                                                                                              'lifetime'),
#                                                                                                                                             ('data',
#                                                                                                                                              OrderedDict([('@type',
#                                                                                                                                                            'nonNegativeInteger')]))]))]))]))]))]),
#                                                                        OrderedDict([('element',
#                                                                                      OrderedDict([('@name',
#                                                                                                    'region'),
#                                                                                                   ('interleave',
#                                                                                                    OrderedDict([('element',
#                                                                                                                  [OrderedDict([('@name',
#                                                                                                                                 'name'),
#                                                                                                                                ('text',
#                                                                                                                                 None)]),
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'config'),
#                                                                                                                                ('choice',
#                                                                                                                                 '@Region_REFS@')])]),
#                                                                                                                 ('optional',
#                                                                                                                  OrderedDict([('element',
#                                                                                                                                OrderedDict([('@name',
#                                                                                                                                              'lifetime'),
#                                                                                                                                             ('data',
#                                                                                                                                              OrderedDict([('@type',
#                                                                                                                                                            'nonNegativeInteger')]))]))])),
#                                                                                                                 ('oneOrMore',
#                                                                                                                  OrderedDict([('element',
#                                                                                                                                OrderedDict([('@name',
#                                                                                                                                              'institution'),
#                                                                                                                                             ('interleave',
#                                                                                                                                              OrderedDict([('element',
#                                                                                                                                                            [OrderedDict([('@name',
#                                                                                                                                                                           'name'),
#                                                                                                                                                                          ('text',
#                                                                                                                                                                           None)]),
#                                                                                                                                                             OrderedDict([('@name',
#                                                                                                                                                                           'config'),
#                                                                                                                                                                          ('choice',
#                                                                                                                                                                           '@Inst_REFS@')])]),
#                                                                                                                                                           ('optional',
#                                                                                                                                                            [OrderedDict([('element',
#                                                                                                                                                                           OrderedDict([('@name',
#                                                                                                                                                                                         'lifetime'),
#                                                                                                                                                                                        ('data',
#                                                                                                                                                                                         OrderedDict([('@type',
#                                                                                                                                                                                                       'nonNegativeInteger')]))]))]),
#                                                                                                                                                             OrderedDict([('element',
#                                                                                                                                                                           OrderedDict([('@name',
#                                                                                                                                                                                         'initialfacilitylist'),
#                                                                                                                                                                                        ('oneOrMore',
#                                                                                                                                                                                         OrderedDict([('element',
#                                                                                                                                                                                                       OrderedDict([('@name',
#                                                                                                                                                                                                                     'entry'),
#                                                                                                                                                                                                                    ('interleave',
#                                                                                                                                                                                                                     OrderedDict([('element',
#                                                                                                                                                                                                                                   [OrderedDict([('@name',
#                                                                                                                                                                                                                                                  'prototype'),
#                                                                                                                                                                                                                                                 ('text',
#                                                                                                                                                                                                                                                  None)]),
#                                                                                                                                                                                                                                    OrderedDict([('@name',
#                                                                                                                                                                                                                                                  'number'),
#                                                                                                                                                                                                                                                 ('data',
#                                                                                                                                                                                                                                                  OrderedDict([('@type',
#                                                                                                                                                                                                                                                                'nonNegativeInteger')]))])])]))]))]))]))])])]))]))]))]))]))])])]))]))]))]))])

# %%
i = x['grammar']['start']['element']
print(i)
# Out:
# OrderedDict([('@name', 'simulation'), ('optional', OrderedDict([('element', OrderedDict([('@name', 'schematype'), ('text', None)]))])), ('interleave', OrderedDict([('optional', OrderedDict([('element', OrderedDict([('@name', 'ui'), ('text', None)]))])), ('element', [OrderedDict([('@name', 'control'), ('interleave', OrderedDict([('optional', [OrderedDict([('element', OrderedDict([('@name', 'simhandle'), ('data', OrderedDict([('@type', 'string')]))]))]), OrderedDict([('element', OrderedDict([('@name', 'decay'), ('text', None)]))]), OrderedDict([('element', OrderedDict([('@name', 'dt'), ('data', OrderedDict([('@type', 'nonNegativeInteger')]))]))]), OrderedDict([('element', OrderedDict([('@name', 'explicit_inventory'), ('data', OrderedDict([('@type', 'boolean')]))]))]), OrderedDict([('element', OrderedDict([('@name', 'explicit_inventory_compact'), ('data', OrderedDict([('@type', 'boolean')]))]))]), OrderedDict([('element', OrderedDict([('@name', 'tolerance_generic'), ('data', OrderedDict([('@type', 'double')]))]))]), OrderedDict([('element', OrderedDict([('@name', 'tolerance_resource'), ('data', OrderedDict([('@type', 'double')]))]))]), OrderedDict([('element', OrderedDict([('@name', 'solver'), ('interleave', OrderedDict([('optional', [OrderedDict([('element', OrderedDict([('@name', 'config'), ('choice', OrderedDict([('element', [OrderedDict([('@name', 'greedy'), ('interleave', OrderedDict([('optional', OrderedDict([('element', OrderedDict([('@name', 'preconditioner'), ('text', None)]))]))]))]), OrderedDict([('@name', 'coin-or'), ('interleave', OrderedDict([('optional', [OrderedDict([('element', OrderedDict([('@name', 'timeout'), ('data', OrderedDict([('@type', 'positiveInteger')]))]))]), OrderedDict([('element', OrderedDict([('@name', 'verbose'), ('data', OrderedDict([('@type', 'boolean')]))]))]), OrderedDict([('element', OrderedDict([('@name', 'mps'), ('data', OrderedDict([('@type', 'boolean')]))]))])])]))])])]))]))]), OrderedDict([('element', OrderedDict([('@name', 'allow_exclusive_orders'), ('data', OrderedDict([('@type', 'boolean')]))]))]), OrderedDict([('element', OrderedDict([('@name', 'exclusive_orders_only'), ('data', OrderedDict([('@type', 'boolean')]))]))])])]))]))])]), ('element', [OrderedDict([('@name', 'duration'), ('data', OrderedDict([('@type', 'nonNegativeInteger')]))]), OrderedDict([('@name', 'startmonth'), ('data', OrderedDict([('@type', 'nonNegativeInteger')]))]), OrderedDict([('@name', 'startyear'), ('data', OrderedDict([('@type', 'nonNegativeInteger')]))])])]))]), OrderedDict([('@name', 'archetypes'), ('oneOrMore', OrderedDict([('element', OrderedDict([('@name', 'spec'), ('interleave', OrderedDict([('optional', [OrderedDict([('element', OrderedDict([('@name', 'path'), ('text', None)]))]), OrderedDict([('element', OrderedDict([('@name', 'lib'), ('text', None)]))]), OrderedDict([('element', OrderedDict([('@name', 'alias'), ('text', None)]))])]), ('element', OrderedDict([('@name', 'name'), ('text', None)]))]))]))]))])]), ('zeroOrMore', [OrderedDict([('element', OrderedDict([('@name', 'commodity'), ('interleave', OrderedDict([('element', [OrderedDict([('@name', 'name'), ('text', None)]), OrderedDict([('@name', 'solution_priority'), ('data', OrderedDict([('@type', 'double')]))])])]))]))]), OrderedDict([('element', OrderedDict([('@name', 'recipe'), ('interleave', OrderedDict([('element', [OrderedDict([('@name', 'name'), ('text', None)]), OrderedDict([('@name', 'basis'), ('text', None)])]), ('oneOrMore', OrderedDict([('element', OrderedDict([('@name', 'nuclide'), ('interleave', OrderedDict([('element', [OrderedDict([('@name', 'id'), ('data', OrderedDict([('@type', 'string')]))]), OrderedDict([('@name', 'comp'), ('data', OrderedDict([('@type', 'double')]))])])]))]))]))]))]))])]), ('oneOrMore', [OrderedDict([('element', OrderedDict([('@name', 'facility'), ('interleave', OrderedDict([('element', [OrderedDict([('@name', 'name'), ('text', None)]), OrderedDict([('@name', 'config'), ('choice', '@Facility_REFS@')])]), ('opt ...

# %%
x['grammar']['start']['element']['interleave']
# Out:
# OrderedDict([('optional',
#               OrderedDict([('element',
#                             OrderedDict([('@name', 'ui'), ('text', None)]))])),
#              ('element',
#               [OrderedDict([('@name', 'control'),
#                             ('interleave',
#                              OrderedDict([('optional',
#                                            [OrderedDict([('element',
#                                                           OrderedDict([('@name',
#                                                                         'simhandle'),
#                                                                        ('data',
#                                                                         OrderedDict([('@type',
#                                                                                       'string')]))]))]),
#                                             OrderedDict([('element',
#                                                           OrderedDict([('@name',
#                                                                         'decay'),
#                                                                        ('text',
#                                                                         None)]))]),
#                                             OrderedDict([('element',
#                                                           OrderedDict([('@name',
#                                                                         'dt'),
#                                                                        ('data',
#                                                                         OrderedDict([('@type',
#                                                                                       'nonNegativeInteger')]))]))]),
#                                             OrderedDict([('element',
#                                                           OrderedDict([('@name',
#                                                                         'explicit_inventory'),
#                                                                        ('data',
#                                                                         OrderedDict([('@type',
#                                                                                       'boolean')]))]))]),
#                                             OrderedDict([('element',
#                                                           OrderedDict([('@name',
#                                                                         'explicit_inventory_compact'),
#                                                                        ('data',
#                                                                         OrderedDict([('@type',
#                                                                                       'boolean')]))]))]),
#                                             OrderedDict([('element',
#                                                           OrderedDict([('@name',
#                                                                         'tolerance_generic'),
#                                                                        ('data',
#                                                                         OrderedDict([('@type',
#                                                                                       'double')]))]))]),
#                                             OrderedDict([('element',
#                                                           OrderedDict([('@name',
#                                                                         'tolerance_resource'),
#                                                                        ('data',
#                                                                         OrderedDict([('@type',
#                                                                                       'double')]))]))]),
#                                             OrderedDict([('element',
#                                                           OrderedDict([('@name',
#                                                                         'solver'),
#                                                                        ('interleave',
#                                                                         OrderedDict([('optional',
#                                                                                       [OrderedDict([('element',
#                                                                                                      OrderedDict([('@name',
#                                                                                                                    'config'),
#                                                                                                                   ('choice',
#                                                                                                                    OrderedDict([('element',
#                                                                                                                                  [OrderedDict([('@name',
#                                                                                                                                                 'greedy'),
#                                                                                                                                                ('interleave',
#                                                                                                                                                 OrderedDict([('optional',
#                                                                                                                                                               OrderedDict([('element',
#                                                                                                                                                                             OrderedDict([('@name',
#                                                                                                                                                                                           'preconditioner'),
#                                                                                                                                                                                          ('text',
#                                                                                                                                                                                           None)]))]))]))]),
#                                                                                                                                   OrderedDict([('@name',
#                                                                                                                                                 'coin-or'),
#                                                                                                                                                ('interleave',
#                                                                                                                                                 OrderedDict([('optional',
#                                                                                                                                                               [OrderedDict([('element',
#                                                                                                                                                                              OrderedDict([('@name',
#                                                                                                                                                                                            'timeout'),
#                                                                                                                                                                                           ('data',
#                                                                                                                                                                                            OrderedDict([('@type',
#                                                                                                                                                                                                          'positiveInteger')]))]))]),
#                                                                                                                                                                OrderedDict([('element',
#                                                                                                                                                                              OrderedDict([('@name',
#                                                                                                                                                                                            'verbose'),
#                                                                                                                                                                                           ('data',
#                                                                                                                                                                                            OrderedDict([('@type',
#                                                                                                                                                                                                          'boolean')]))]))]),
#                                                                                                                                                                OrderedDict([('element',
#                                                                                                                                                                              OrderedDict([('@name',
#                                                                                                                                                                                            'mps'),
#                                                                                                                                                                                           ('data',
#                                                                                                                                                                                            OrderedDict([('@type',
#                                                                                                                                                                                                          'boolean')]))]))])])]))])])]))]))]),
#                                                                                        OrderedDict([('element',
#                                                                                                      OrderedDict([('@name',
#                                                                                                                    'allow_exclusive_orders'),
#                                                                                                                   ('data',
#                                                                                                                    OrderedDict([('@type',
#                                                                                                                                  'boolean')]))]))]),
#                                                                                        OrderedDict([('element',
#                                                                                                      OrderedDict([('@name',
#                                                                                                                    'exclusive_orders_only'),
#                                                                                                                   ('data',
#                                                                                                                    OrderedDict([('@type',
#                                                                                                                                  'boolean')]))]))])])]))]))])]),
#                                           ('element',
#                                            [OrderedDict([('@name', 'duration'),
#                                                          ('data',
#                                                           OrderedDict([('@type',
#                                                                         'nonNegativeInteger')]))]),
#                                             OrderedDict([('@name',
#                                                           'startmonth'),
#                                                          ('data',
#                                                           OrderedDict([('@type',
#                                                                         'nonNegativeInteger')]))]),
#                                             OrderedDict([('@name',
#                                                           'startyear'),
#                                                          ('data',
#                                                           OrderedDict([('@type',
#                                                                         'nonNegativeInteger')]))])])]))]),
#                OrderedDict([('@name', 'archetypes'),
#                             ('oneOrMore',
#                              OrderedDict([('element',
#                                            OrderedDict([('@name', 'spec'),
#                                                         ('interleave',
#                                                          OrderedDict([('optional',
#                                                                        [OrderedDict([('element',
#                                                                                       OrderedDict([('@name',
#                                                                                                     'path'),
#                                                                                                    ('text',
#                                                                                                     None)]))]),
#                                                                         OrderedDict([('element',
#                                                                                       OrderedDict([('@name',
#                                                                                                     'lib'),
#                                                                                                    ('text',
#                                                                                                     None)]))]),
#                                                                         OrderedDict([('element',
#                                                                                       OrderedDict([('@name',
#                                                                                                     'alias'),
#                                                                                                    ('text',
#                                                                                                     None)]))])]),
#                                                                       ('element',
#                                                                        OrderedDict([('@name',
#                                                                                      'name'),
#                                                                                     ('text',
#                                                                                      None)]))]))]))]))])]),
#              ('zeroOrMore',
#               [OrderedDict([('element',
#                              OrderedDict([('@name', 'commodity'),
#                                           ('interleave',
#                                            OrderedDict([('element',
#                                                          [OrderedDict([('@name',
#                                                                         'name'),
#                                                                        ('text',
#                                                                         None)]),
#                                                           OrderedDict([('@name',
#                                                                         'solution_priority'),
#                                                                        ('data',
#                                                                         OrderedDict([('@type',
#                                                                                       'double')]))])])]))]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name', 'recipe'),
#                                           ('interleave',
#                                            OrderedDict([('element',
#                                                          [OrderedDict([('@name',
#                                                                         'name'),
#                                                                        ('text',
#                                                                         None)]),
#                                                           OrderedDict([('@name',
#                                                                         'basis'),
#                                                                        ('text',
#                                                                         None)])]),
#                                                         ('oneOrMore',
#                                                          OrderedDict([('element',
#                                                                        OrderedDict([('@name',
#                                                                                      'nuclide'),
#                                                                                     ('interleave',
#                                                                                      OrderedDict([('element',
#                                                                                                    [OrderedDict([('@name',
#                                                                                                                   'id'),
#                                                                                                                  ('data',
#                                                                                                                   OrderedDict([('@type',
#                                                                                                                                 'string')]))]),
#                                                                                                     OrderedDict([('@name',
#                                                                                                                   'comp'),
#                                                                                                                  ('data',
#                                                                                                                   OrderedDict([('@type',
#                                                                                                                                 'double')]))])])]))]))]))]))]))])]),
#              ('oneOrMore',
#               [OrderedDict([('element',
#                              OrderedDict([('@name', 'facility'),
#                                           ('interleave',
#                                            OrderedDict([('element',
#                                                          [OrderedDict([('@name',
#                                                                         'name'),
#                                                                        ('text',
#                                                                         None)]),
#                                                           OrderedDict([('@name',
#                                                                         'config'),
#                                                                        ('choice',
#                                                                         '@Facility_REFS@')])]),
#                                                         ('optional',
#                                                          OrderedDict([('element',
#                                                                        OrderedDict([('@name',
#                                                                                      'lifetime'),
#                                                                                     ('data',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'nonNegativeInteger')]))]))]))]))]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name', 'region'),
#                                           ('interleave',
#                                            OrderedDict([('element',
#                                                          [OrderedDict([('@name',
#                                                                         'name'),
#                                                                        ('text',
#                                                                         None)]),
#                                                           OrderedDict([('@name',
#                                                                         'config'),
#                                                                        ('choice',
#                                                                         '@Region_REFS@')])]),
#                                                         ('optional',
#                                                          OrderedDict([('element',
#                                                                        OrderedDict([('@name',
#                                                                                      'lifetime'),
#                                                                                     ('data',
#                                                                                      OrderedDict([('@type',
#                                                                                                    'nonNegativeInteger')]))]))])),
#                                                         ('oneOrMore',
#                                                          OrderedDict([('element',
#                                                                        OrderedDict([('@name',
#                                                                                      'institution'),
#                                                                                     ('interleave',
#                                                                                      OrderedDict([('element',
#                                                                                                    [OrderedDict([('@name',
#                                                                                                                   'name'),
#                                                                                                                  ('text',
#                                                                                                                   None)]),
#                                                                                                     OrderedDict([('@name',
#                                                                                                                   'config'),
#                                                                                                                  ('choice',
#                                                                                                                   '@Inst_REFS@')])]),
#                                                                                                   ('optional',
#                                                                                                    [OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'lifetime'),
#                                                                                                                                ('data',
#                                                                                                                                 OrderedDict([('@type',
#                                                                                                                                               'nonNegativeInteger')]))]))]),
#                                                                                                     OrderedDict([('element',
#                                                                                                                   OrderedDict([('@name',
#                                                                                                                                 'initialfacilitylist'),
#                                                                                                                                ('oneOrMore',
#                                                                                                                                 OrderedDict([('element',
#                                                                                                                                               OrderedDict([('@name',
#                                                                                                                                                             'entry'),
#                                                                                                                                                            ('interleave',
#                                                                                                                                                             OrderedDict([('element',
#                                                                                                                                                                           [OrderedDict([('@name',
#                                                                                                                                                                                          'prototype'),
#                                                                                                                                                                                         ('text',
#                                                                                                                                                                                          None)]),
#                                                                                                                                                                            OrderedDict([('@name',
#                                                                                                                                                                                          'number'),
#                                                                                                                                                                                         ('data',
#                                                                                                                                                                                          OrderedDict([('@type',
#                                                                                                                                                                                                        'nonNegativeInteger')]))])])]))]))]))]))])])]))]))]))]))]))])])])

# %%
i = x['grammar']['start']['element']['interleave']
i.keys()
# Out:
# odict_keys(['optional', 'element', 'zeroOrMore', 'oneOrMore'])

# %%
for j in i['element']:
    print(j['@name'])
    for k in j.keys():
        pprint(j[k])
# Out:
# control
# 'control'
# OrderedDict([('optional',
#               [OrderedDict([('element',
#                              OrderedDict([('@name', 'simhandle'),
#                                           ('data',
#                                            OrderedDict([('@type',
#                                                          'string')]))]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name', 'decay'),
#                                           ('text', None)]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name', 'dt'),
#                                           ('data',
#                                            OrderedDict([('@type',
#                                                          'nonNegativeInteger')]))]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name', 'explicit_inventory'),
#                                           ('data',
#                                            OrderedDict([('@type',
#                                                          'boolean')]))]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name',
#                                            'explicit_inventory_compact'),
#                                           ('data',
#                                            OrderedDict([('@type',
#                                                          'boolean')]))]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name', 'tolerance_generic'),
#                                           ('data',
#                                            OrderedDict([('@type',
#                                                          'double')]))]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name', 'tolerance_resource'),
#                                           ('data',
#                                            OrderedDict([('@type',
#                                                          'double')]))]))]),
#                OrderedDict([('element',
#                              OrderedDict([('@name', 'solver'),
#                                           ('interleave',
#                                            OrderedDict([('optional',
#                                                          [OrderedDict([('element',
#                                                                         OrderedDict([('@name',
#                                                                                       'config'),
#                                                                                      ('choice',
#                                                                                       OrderedDict([('element',
#                                                                                                     [OrderedDict([('@name',
#                                                                                                                    'greedy'),
#                                                                                                                   ('interleave',
#                                                                                                                    OrderedDict([('optional',
#                                                                                                                                  OrderedDict([('element',
#                                                                                                                                                OrderedDict([('@name',
#                                                                                                                                                              'preconditioner'),
#                                                                                                                                                             ('text',
#                                                                                                                                                              None)]))]))]))]),
#                                                                                                      OrderedDict([('@name',
#                                                                                                                    'coin-or'),
#                                                                                                                   ('interleave',
#                                                                                                                    OrderedDict([('optional',
#                                                                                                                                  [OrderedDict([('element',
#                                                                                                                                                 OrderedDict([('@name',
#                                                                                                                                                               'timeout'),
#                                                                                                                                                              ('data',
#                                                                                                                                                               OrderedDict([('@type',
#                                                                                                                                                                             'positiveInteger')]))]))]),
#                                                                                                                                   OrderedDict([('element',
#                                                                                                                                                 OrderedDict([('@name',
#                                                                                                                                                               'verbose'),
#                                                                                                                                                              ('data',
#                                                                                                                                                               OrderedDict([('@type',
#                                                                                                                                                                             'boolean')]))]))]),
#                                                                                                                                   OrderedDict([('element',
#                                                                                                                                                 OrderedDict([('@name',
#                                                                                                                                                               'mps'),
#                                                                                                                                                              ('data',
#                                                                                                                                                               OrderedDict([('@type',
#                                                                                                                                                                             'boolean')]))]))])])]))])])]))]))]),
#                                                           OrderedDict([('element',
#                                                                         OrderedDict([('@name',
#                                                                                       'allow_exclusive_orders'),
#                                                                                      ('data',
#                                                                                       OrderedDict([('@type',
#                                                                                                     'boolean')]))]))]),
#                                                           OrderedDict([('element',
#                                                                         OrderedDict([('@name',
#                                                                                       'exclusive_orders_only'),
#                                                                                      ('data',
#                                                                                       OrderedDict([('@type',
#                                                                                                     'boolean')]))]))])])]))]))])]),
#              ('element',
#               [OrderedDict([('@name', 'duration'),
#                             ('data',
#                              OrderedDict([('@type', 'nonNegativeInteger')]))]),
#                OrderedDict([('@name', 'startmonth'),
#                             ('data',
#                              OrderedDict([('@type', 'nonNegativeInteger')]))]),
#                OrderedDict([('@name', 'startyear'),
#                             ('data',
#                              OrderedDict([('@type',
#                                            'nonNegativeInteger')]))])])])
# archetypes
# 'archetypes'
# OrderedDict([('element',
#               OrderedDict([('@name', 'spec'),
#                            ('interleave',
#                             OrderedDict([('optional',
#                                           [OrderedDict([('element',
#                                                          OrderedDict([('@name',
#                                                                        'path'),
#                                                                       ('text',
#                                                                        None)]))]),
#                                            OrderedDict([('element',
#                                                          OrderedDict([('@name',
#                                                                        'lib'),
#                                                                       ('text',
#                                                                        None)]))]),
#                                            OrderedDict([('element',
#                                                          OrderedDict([('@name',
#                                                                        'alias'),
#                                                                       ('text',
#                                                                        None)]))])]),
#                                          ('element',
#                                           OrderedDict([('@name', 'name'),
#                                                        ('text', None)]))]))]))])

# %%
for j in i['zeroOrMore']:
    print(j['element']['@name'])
# Out:
# commodity
# recipe

# %%
# Out:
# OrderedDict([('element',
#               OrderedDict([('@name', 'recipe'),
#                            ('interleave',
#                             OrderedDict([('element',
#                                           [OrderedDict([('@name', 'name'),
#                                                         ('text', None)]),
#                                            OrderedDict([('@name', 'basis'),
#                                                         ('text', None)])]),
#                                          ('oneOrMore',
#                                           OrderedDict([('element',
#                                                         OrderedDict([('@name',
#                                                                       'nuclide'),
#                                                                      ('interleave',
#                                                                       OrderedDict([('element',
#                                                                                     [OrderedDict([('@name',
#                                                                                                    'id'),
#                                                                                                   ('data',
#                                                                                                    OrderedDict([('@type',
#                                                                                                                  'string')]))]),
#                                                                                      OrderedDict([('@name',
#                                                                                                    'comp'),
#                                                                                                   ('data',
#                                                                                                    OrderedDict([('@type',
#                                                                                                                  'double')]))])])]))]))]))]))]))])

# %%
for j in i['oneOrMore']:
    print(j['element']['@name'])
# Out:
# facility
# region

# %%
for j in i['optional']:
    print(j)
# Out:
# element

# %%
def convert_valtype(valtype):
    # conversion from Cyclus valtype [key]
    # to Workbench ValType [val]
    conversion_dict = {'string': 'String',
                       'nonNegativeInteger': 'Int',
                       'boolean': 'Int',
                       'double': 'Real',
                       'positiveInteger': 'Int',
                       'float': 'Real',
                       'double': 'Real',
                       'duration': 'Int',
                       'integer': 'Int',
                       'nonPositiveInteger': 'Int',
                       'negativeInteger': 'Int',
                       'long': 'Real',
                       'int': 'Int',
                       }

    additional_dict = {'nonNegativeInteger': {'MinValInc': 0},
                       'positiveInteger': {'MinValExc': 0},
                       'boolean': {'ValEnums': [0, 1]},
                       'duration': {'MinValInc': 0},
                       'nonPositiveInteger': {'MaxValInc': 0},
                       'negativeInteger': {'MaxValExc': 0},
                       }
    d = {'valType': conversion_dict[valtype]}
    if valtype in additional_dict:
        for key, val in additional_dict[valtype].items():
            d[key] = val
    return d

def convert_num_limits(limit_type):
    conversion_dict = {'oneOrMore': {'ChildAtLeastOne': },
                       'zeroOrMore': {'MinOccurs': 0}
                       }


def change_element(element_dict):
    d = {element_dict['@name']: convert_valtype(element_dict['data']['@type'])}

# %%
"""
simulation{InputType=Sequence InputName='cylcus'
InputTmpl='cyclus.seq' Description="Agent-based fuel cycle simulation"
control {InputType=ParenArray MinOccurs=1 MaxOccurs=1
    `import("../components/")}
archetypes {}
control {}
facility {}
recipe {}
region {}
"""
# Out:
# '\ncyclus{InputType=Sequence InputName=\'cylcus\'\nInputTmpl=\'cyclus.seq\' Description="Agent-based fuel cycle simulation"}\n'

# %%
# template file
"""
{
"simulation": {
    "archetypes" : {
    "spec": []
    },
    "control": {"duration": duration_here,
                "startmonth": startmonth_here,
                "startyear": startyear_here},
    "facility": [],
    "recipe": [],
    "region": [],
}
}"""
# archetypes spec automatically filled from distribution
# Out:
# '\n{\n"simulation": {\n    "archetypes" : {\n    "spec": []\n    },\n    "control": {"duration": duration_here,\n                "startmonth": startmonth_here,\n                "startyear": startyear_here},\n    "facility": [],\n    "recipe": [],\n    "region": [],\n}\n}'

# %%
i = x['grammar']['start']['element']['interleave']['element']
ctrl = i[0]
recipe = x['grammar']['start']['element']['interleave']['zeroOrMore'][1]

def fui_generator(tree):
    fui_str = ''
    fui_str += '"%s"{\n' %tree['@name']
    fui_str += '\ttype=object\n'
    # get essential variables first
    for entry in tree['interleave']['element']:
        options = parse_options(entry)
        fui_str += '\t%s{\n\t\t%s\n\t\t}\n' %(entry['@name'], '\n\t\t'.join(options))
    # optional variables
    for entry in tree['interleave']['optional']:
        entry = entry['element']
        options = parse_options(entry)
        options.append('need=optional')
        fui_str += '\t%s{\n\t\t%s\n\t\t}\n' %(entry['@name'], '\n\t\t'.join(options))
    print(fui_str)
    
def convert_valtype(val):
    if 'string' in val.lower() or 'str' in val.lower():
        return 'string'
    else:
        return 'real'

def parse_options(entry_dict):
    option_list = []

    if 'data' not in entry_dict:
        if 'text' in entry_dict.keys():
            return ['type=string']
        else:
            return []
    for key, val in entry_dict['data'].items():
        if key == '@type':
            option_list.append('type=%s' %convert_valtype(val))
        else:
            print('what else %s' %key)
    
    return option_list
        
fui_generator(recipe)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-110-3979332b02e5> in <module>
#      41     return option_list
#      42
# ---> 43 fui_generator(recipe)
#      44
#      45
#
# <ipython-input-110-3979332b02e5> in fui_generator(tree)
#       5 def fui_generator(tree):
#       6     fui_str = ''
# ----> 7     fui_str += '"%s"{\n' %tree['@name']
#       8     fui_str += '\ttype=object\n'
#       9     # get essential variables first
#
# KeyError: '@name'

# %%
recipe
# Out:
# OrderedDict([('element',
#               OrderedDict([('@name', 'recipe'),
#                            ('interleave',
#                             OrderedDict([('element',
#                                           [OrderedDict([('@name', 'name'),
#                                                         ('text', None)]),
#                                            OrderedDict([('@name', 'basis'),
#                                                         ('text', None)])]),
#                                          ('oneOrMore',
#                                           OrderedDict([('element',
#                                                         OrderedDict([('@name',
#                                                                       'nuclide'),
#                                                                      ('interleave',
#                                                                       OrderedDict([('element',
#                                                                                     [OrderedDict([('@name',
#                                                                                                    'id'),
#                                                                                                   ('data',
#                                                                                                    OrderedDict([('@type',
#                                                                                                                  'string')]))]),
#                                                                                      OrderedDict([('@name',
#                                                                                                    'comp'),
#                                                                                                   ('data',
#                                                                                                    OrderedDict([('@type',
#                                                                                                                  'double')]))])])]))]))]))]))]))])

# %%
for i in ctrl['interleave']['optional']:
    try:
        print(i['element']['data'])
    except:
        print('no data', '\t', i)
# Out:
# OrderedDict([('@type', 'string')])
# no data 	 OrderedDict([('element', OrderedDict([('@name', 'decay'), ('text', None)]))])
# OrderedDict([('@type', 'nonNegativeInteger')])
# OrderedDict([('@type', 'boolean')])
# OrderedDict([('@type', 'boolean')])
# OrderedDict([('@type', 'double')])
# OrderedDict([('@type', 'double')])
# no data 	 OrderedDict([('element', OrderedDict([('@name', 'solver'), ('interleave', OrderedDict([('optional', [OrderedDict([('element', OrderedDict([('@name', 'config'), ('choice', OrderedDict([('element', [OrderedDict([('@name', 'greedy'), ('interleave', OrderedDict([('optional', OrderedDict([('element', OrderedDict([('@name', 'preconditioner'), ('text', None)]))]))]))]), OrderedDict([('@name', 'coin-or'), ('interleave', OrderedDict([('optional', [OrderedDict([('element', OrderedDict([('@name', 'timeout'), ('data', OrderedDict([('@type', 'positiveInteger')]))]))]), OrderedDict([('element', OrderedDict([('@name', 'verbose'), ('data', OrderedDict([('@type', 'boolean')]))]))]), OrderedDict([('element', OrderedDict([('@name', 'mps'), ('data', OrderedDict([('@type', 'boolean')]))]))])])]))])])]))]))]), OrderedDict([('element', OrderedDict([('@name', 'allow_exclusive_orders'), ('data', OrderedDict([('@type', 'boolean')]))]))]), OrderedDict([('element', OrderedDict([('@name', 'exclusive_orders_only'), ('data', OrderedDict([('@type', 'boolean')]))]))])])]))]))])

# %%
for i in ctrl['interleave']['optional']:
    print(i)
    print('\n')
# Out:
# OrderedDict([('element', OrderedDict([('@name', 'simhandle'), ('data', OrderedDict([('@type', 'string')]))]))])
#
#
# OrderedDict([('element', OrderedDict([('@name', 'decay'), ('text', None)]))])
#
#
# OrderedDict([('element', OrderedDict([('@name', 'dt'), ('data', OrderedDict([('@type', 'nonNegativeInteger')]))]))])
#
#
# OrderedDict([('element', OrderedDict([('@name', 'explicit_inventory'), ('data', OrderedDict([('@type', 'boolean')]))]))])
#
#
# OrderedDict([('element', OrderedDict([('@name', 'explicit_inventory_compact'), ('data', OrderedDict([('@type', 'boolean')]))]))])
#
#
# OrderedDict([('element', OrderedDict([('@name', 'tolerance_generic'), ('data', OrderedDict([('@type', 'double')]))]))])
#
#
# OrderedDict([('element', OrderedDict([('@name', 'tolerance_resource'), ('data', OrderedDict([('@type', 'double')]))]))])
#
#
# OrderedDict([('element', OrderedDict([('@name', 'solver'), ('interleave', OrderedDict([('optional', [OrderedDict([('element', OrderedDict([('@name', 'config'), ('choice', OrderedDict([('element', [OrderedDict([('@name', 'greedy'), ('interleave', OrderedDict([('optional', OrderedDict([('element', OrderedDict([('@name', 'preconditioner'), ('text', None)]))]))]))]), OrderedDict([('@name', 'coin-or'), ('interleave', OrderedDict([('optional', [OrderedDict([('element', OrderedDict([('@name', 'timeout'), ('data', OrderedDict([('@type', 'positiveInteger')]))]))]), OrderedDict([('element', OrderedDict([('@name', 'verbose'), ('data', OrderedDict([('@type', 'boolean')]))]))]), OrderedDict([('element', OrderedDict([('@name', 'mps'), ('data', OrderedDict([('@type', 'boolean')]))]))])])]))])])]))]))]), OrderedDict([('element', OrderedDict([('@name', 'allow_exclusive_orders'), ('data', OrderedDict([('@type', 'boolean')]))]))]), OrderedDict([('element', OrderedDict([('@name', 'exclusive_orders_only'), ('data', OrderedDict([('@type', 'boolean')]))]))])])]))]))])

# %%
highlight_str ="""
rule("bracket_open") {
    pattern = "{"
    bold = ture
    forground {
        red = 0
        green = 128
        blue = 0
    }
rule("bracket_close") {
    pattern = "}"
    bold = ture
    forground {
        red = 0
        green = 128
        blue = 0
    }

}"""

# %%
schema_path = '/Users/4ib/Desktop/git/cyclus_gui/neams/cyclus.sch'
template_dir = '/Users/4ib/Desktop/git/cyclus_gui/neams/templates/'
highlight_dir = '/Users/4ib/Desktop/git/cyclus_gui/neams/cyclus.wbh'

# what about the validator
# no highlighter for now
grammar_str = """name= Cyclus
enabled = true

parser = JSON
schema = '%s'

templates = '%s'

highlighter = "%s"

extensions = [cyclus]
""" %(schema_path, template_dir, highlight_dir)

sch_str = """simulation{
    Description="Agent-based fuel cycle simulator"
    InputTmpl="init_template"
    control {MinOccurs=1
             MaxOccurs=1
             simhandle={
                 MinOccurs=0
                 MaxOccurs=1
                 ValType=String
             }
             duration={
                 MinOccurs=1
                 MaxOccurs=1
                 ValType=Real
             }
    }
}"""

init_template = """{
"simulation": {
    "archetypes" : {
    "spec": [ARCHETYPES_HERE_SHOULD_BE_AUTOFILLED_DONT_WORRY]
    },
    "control": {"duration": DURATION_HERE,
                "startmonth": STARTMONTH_HERE,
                "startyear": STARTYEAR_HERE},
    "facility": [FACILITIES_HERE],
    "recipe": [RECIPES_HERE],
    "region": [REGIONS_HERE],
}
}"""

template_dict = {'init_template': init_template}
# archetypes spec automatically filled from distribution

grammar_path = '/Users/4ib/.workbench/2.0.0/grammars/cyclus.wbg'
highlight_path = '/Users/4ib/.workbench/2.0.0/grammars/cyclus.wbh'

with open(grammar_path, 'w') as f:
    f.write(grammar_str)

with open(schema_path, 'w') as f:
    f.write(sch_str)
with open('/Users/4ib/Downloads/Workbench-Darwin/etc/InputDefinitions/finaloutput/cyclus.sch', 'w') as f:
    f.write(sch_str)
    
with open(highlight_dir, 'w') as f:
    f.write(highlight_str)

for key, val in template_dict.items():
    with open(os.path.join(template_dir, key+'.tmpl'), 'w') as f:
        f.write(val)

# %%
! open ~/Downloads/Workbench-Darwin/bin/Workbench

# %% [markdown]
# 1. put the grammar file into .workbench/2.0.0/grammars/*.wbh
